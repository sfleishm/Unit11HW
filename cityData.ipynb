# %%
import pandas as pd

# %%
df_csv = pd.read_csv('citydata.csv')

# %%
df = pd.DataFrame(df_csv)

# %%
df
# Out:
#      Unnamed: 0                   City  Cloudiness Country        Date  \
# 0             0             Codrington          75      AU  1565886703
# 1             1            Tuktoyaktuk          90      CA  1565886704
# 2             2             Chokurdakh          53      RU  1565886704
# 3             3                  Kozan          75      TR  1565886705
# 4             4                 Hobart          75      AU  1565886705
# 5             5              Nhulunbuy           1      AU  1565886705
# 6             6                 Seddon          75      AU  1565886706
# 7             7                 Narsaq          20      GL  1565886706
# 8             8                 Salaga          48      GH  1565886707
# 9             9              Bathsheba          40      BB  1565886707
# 10           10              Jamestown          61      AU  1565886707
# 11           11                   Hilo          90      US  1565886708
# ...

# %%
newDF = df.drop(columns=["Unnamed: 0"])

# %%
newDF
# Out:
#                       City  Cloudiness Country        Date  Humidity    Lat  \
# 0               Codrington          75      AU  1565886703        93 -28.95
# 1              Tuktoyaktuk          90      CA  1565886704        93  69.44
# 2               Chokurdakh          53      RU  1565886704        73  70.62
# 3                    Kozan          75      TR  1565886705        70  37.45
# 4                   Hobart          75      AU  1565886705        81 -42.88
# 5                Nhulunbuy           1      AU  1565886705        94 -12.18
# 6                   Seddon          75      AU  1565886706        54 -37.81
# 7                   Narsaq          20      GL  1565886706        38  60.91
# 8                   Salaga          48      GH  1565886707        84   8.55
# 9                Bathsheba          40      BB  1565886707        66  13.22
# 10               Jamestown          61      AU  1565886707        28 -33.21
# ...

# %%
newDF.to_html('citydataHTML.html', justify='left')
